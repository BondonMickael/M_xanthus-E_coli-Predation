# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import riptide
import cobra
from cobra.io import read_sbml_model, write_sbml_model
from cobra.flux_analysis import flux_variability_analysis
from tqdm import tqdm

# %%
M_xanthus = read_sbml_model("/home/mickael/github/M_xanthus-E_coli-Predation/M_xanthus_model_V3_hdca.xml")
M_xanthus
# Out:
# <Model myxo_model at 0x7b8f0daab7a0>

# %%
transcript = riptide.read_transcription_file('/home/mickael/github/M_xanthus-E_coli-Predation/data/Raw/WT_vs_4preys_RIPTiDe.csv', sep = ",", header=True)

riptide_object_1 = riptide.contextualize(model=M_xanthus)

riptide.save_output(riptide_obj=riptide_object_1, path='/home/mickael/github/M_xanthus-E_coli-Predation/notebooks')
# Out:
# WARNING: No transcriptome provided. Analyzing most parsimonious state
#
# Initializing model and integrating transcriptomic data...
# Pruning zero flux subnetworks...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 transcript = riptide.read_transcription_file('/home/mickael/github/M_xanthus-E_coli-Predation/data/Raw/WT_vs_4preys_RIPTiDe.csv', sep = ",", header=True)
# ----> 3 riptide_object_1 = riptide.contextualize(model=M_xanthus)
#       5 riptide.save_output(riptide_obj=riptide_object_1, path='/home/mickael/github/M_xanthus-E_coli-Predation/notebooks')
#
# File ~/miniconda3/envs/RIPTiDe/lib/python3.12/site-packages/riptide.py:804, in contextualize(model, transcriptome, samples, silent, prune, fraction, minimum, conservative, objective, additive, direct, set_bounds, tasks, task_frac, exclude, gpr, threshold, phase)
# ...
