# %% [markdown]
# **Import package + model**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cobra
from cobra.io import read_sbml_model, write_sbml_model
from cobra.flux_analysis import flux_variability_analysis
from tqdm import tqdm

# %%
M_xanthus = read_sbml_model(
    "../M_xanthus_model_V2.sbml"
)  # import the Myxococcus xanthus model
M_xanthus
# Out:
# <Model myxo_model at 0x744f4412d2e0>

# %%
E_coli = read_sbml_model("../E_coli_model.sbml")
E_coli
# Out:
# <Model iML1515 at 0x744f3e7abe90>

# %% [markdown]
# **Adding Reactions**

# %% [markdown]
# For Escherichia coli

# %%
Ereaction = cobra.Reaction("PR_BIOMASS_PREY")
Ereaction.name = "Predation Biomass"
Ereaction.subsystem = ""
Ereaction.lower_bound = 0.0  # This is the default
Ereaction.upper_bound = 1000.0  # This is the default

spmd_c = (
    E_coli.metabolites.spmd_c
)  # carbon source from exchange used in biomass reaction
pheme_c = E_coli.metabolites.pheme_c
val_L_c = E_coli.metabolites.val__L_c  # imported AA
ile_L_c = E_coli.metabolites.ile__L_c
leu_L_c = E_coli.metabolites.leu__L_c
lys_L_c = E_coli.metabolites.lys__L_c
his_L_c = E_coli.metabolites.his__L_c
cys_L_c = E_coli.metabolites.cys__L_c
gly_c = E_coli.metabolites.gly_c
cgly_c = E_coli.metabolites.cgly_c
pro_L_c = E_coli.metabolites.pro__L_c
alaala_c = E_coli.metabolites.alaala_c
glu_L_c = E_coli.metabolites.glu__L_c
met_L_c = E_coli.metabolites.met__L_c
thr_L_c = E_coli.metabolites.thr__L_c
fru_c = E_coli.metabolites.fru_c  # import fructose
man_c = E_coli.metabolites.man_c
# malt_c = E_coli.metabolites.malt_c
acald_c = E_coli.metabolites.acald_c  # import FA
acac_c = E_coli.metabolites.acac_c
# glyc3p_c = E_coli.metabolites.glyc3p_c
# gam_c = E_coli.metabolites.gam_c
fum_c = E_coli.metabolites.fum_c  # should put directly the amino acids? asp and arg?
orn_c = E_coli.metabolites.orn_c
# succ_c = E_coli.metabolites.succ_c
pi_c = E_coli.metabolites.pi_c  # from research
zn2_c = E_coli.metabolites.zn2_c  # Metals
mn2_c = E_coli.metabolites.mn2_c
mg2_c = E_coli.metabolites.mg2_c
k_c = E_coli.metabolites.k_c
cu2_c = E_coli.metabolites.cu2_c
cobalt2_c = E_coli.metabolites.cobalt2_c
cl_c = E_coli.metabolites.cl_c
ca2_c = E_coli.metabolites.ca2_c
so4_c = E_coli.metabolites.so4_c
fe3_c = E_coli.metabolites.fe3_c

Ereaction.add_metabolites(
    {
        spmd_c: -0.006744,
        pheme_c: -0.000223,
        val_L_c: -0.411184,
        ile_L_c: -0.282306,
        leu_L_c: -0.437778,
        lys_L_c: -0.333448,
        his_L_c: -0.092056,
        cys_L_c: -0.088988,
        gly_c: -0.595297,
        cgly_c: -1,
        pro_L_c: -0.214798,
        alaala_c: -0.499149,
        fru_c: -1,
        man_c: -1,
        # Smalt_c: -1,
        glu_L_c: -0.255712,
        met_L_c: -0.149336,
        thr_L_c: -0.246506,
        # gam_c: -1,
        fum_c: -1,
        orn_c: -1,
        # succ_c: -1,
        acald_c: -1,
        acac_c: -1,
        # glyc3p_c: -1,
        pi_c: -1,
        zn2_c: -0.000324,
        mn2_c: -0.000658,
        mg2_c: -0.008253,
        k_c: -0.18569,
        cu2_c: -0.000674,
        cobalt2_c: -2.4e-05,
        cl_c: -0.004952,
        ca2_c: -0.004952,
        so4_c: -0.004126,
        fe3_c: -0.007428,
    }
)  # add the metabolites to the reaction

Ereaction.gene_reaction_rule = ""
E_coli.add_reactions([Ereaction])
E_coli.reactions.PR_BIOMASS_PREY
# Out:
# <Reaction PR_BIOMASS_PREY at 0x744f3f836600>

# %% [markdown]
# For Myxococcus xanthus

# %%
Mreaction = cobra.Reaction("PR_BIOMASS_PRED")
Mreaction.name = "Predation Biomass"
Mreaction.subsystem = ""
Mreaction.lower_bound = 0.0  # This is the default
Mreaction.upper_bound = 1000.0  # This is the default

spmd_e = (
    M_xanthus.metabolites.spmd_e
)  # carbon source from exchange used in biomass reaction
pheme_e = M_xanthus.metabolites.pheme_e
val_L_e = M_xanthus.metabolites.val_L_e  # imported AA
ile_L_e = M_xanthus.metabolites.ile_L_e
leu_L_e = M_xanthus.metabolites.leu_L_e
lys_L_e = M_xanthus.metabolites.lys_L_e
his_L_e = M_xanthus.metabolites.his_L_e
gly_cys_L_e = M_xanthus.metabolites.gly_cys_L_e
cgly_e = M_xanthus.metabolites.cgly_e
pro_L_e = M_xanthus.metabolites.pro_L_e
alaala_e = M_xanthus.metabolites.alaala_e
glu_L_c = M_xanthus.metabolites.glu_L_c
met_L_e = M_xanthus.metabolites.met_L_e
thr_L_e = M_xanthus.metabolites.thr_L_e
fru_e = M_xanthus.metabolites.fru_e  # import fructose
man_e = M_xanthus.metabolites.man_e
# malt_e = M_xanthus.metabolites.malt_e
acald_e = M_xanthus.metabolites.acald_e  # import FA
acac_e = M_xanthus.metabolites.acac_e
# glyc3p_e = M_xanthus.metabolites.glyc3p_e
# gam_e = M_xanthus.metabolites.gam_e
fum_e = M_xanthus.metabolites.fum_e  # should put directly the amino acids? asp and arg?
orn_e = M_xanthus.metabolites.orn_e
# succ_e = M_xanthus.metabolites.succ_e
pi_e = M_xanthus.metabolites.pi_e  # from research
zn2_e = M_xanthus.metabolites.zn2_e  # Metals
mn2_e = M_xanthus.metabolites.mn2_e
mg2_e = M_xanthus.metabolites.mg2_e
k_e = M_xanthus.metabolites.k_e
cu2_e = M_xanthus.metabolites.cu2_e
cobalt2_e = M_xanthus.metabolites.cobalt2_e
cl_e = M_xanthus.metabolites.cl_e
ca2_e = M_xanthus.metabolites.ca2_e
so4_e = M_xanthus.metabolites.so4_e
fe3_e = M_xanthus.metabolites.Fe3_e

Mreaction.add_metabolites(
    {
        spmd_e: 1,
        pheme_e: 1,
        val_L_e: 1,
        ile_L_e: 1,
        leu_L_e: 1,
        lys_L_e: 1,
        his_L_e: 1,
        gly_cys_L_e: 1,
        cgly_e: 1,
        pro_L_e: 1,
        alaala_e: 1,
        fru_e: 1,
        man_e: 1,
        # Smalt_e: 1,
        glu_L_c: 1,
        met_L_e: 1,
        thr_L_e: 1,
        # gam_e: 1,
        fum_e: 1,
        orn_e: 1,
        # succ_e: 1,
        acald_e: 1,
        acac_e: 1,
        # glyc3p_e: 1,
        pi_e: 1,
        zn2_e: 1,
        mn2_e: 1,
        mg2_e: 1,
        k_e: 1,
        cu2_e: 1,
        cobalt2_e: 1,
        cl_e: 1,
        ca2_e: 1,
        so4_e: 1,
        fe3_e: 1,
    }
)  # add the metabolites to the reaction

Mreaction.gene_reaction_rule = ""
M_xanthus.add_reactions([Mreaction])
M_xanthus.reactions.PR_BIOMASS_PRED
# Out:
# <Reaction PR_BIOMASS_PRED at 0x744f3f836960>

# %% [markdown]
# Change importation limit

# %%
M_xanthus.reactions.EX_spmd_e.lower_bound = 0  # define the bound to 0 for metabolites in the reactions  # ? - not imported by E.coli / used for Biomass
M_xanthus.reactions.EX_pheme_e.lower_bound = (
    0  # amino acid - from Data / not imported by E.coli
)
M_xanthus.reactions.EX_val_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_ile_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_leu_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_lys_L_e.lower_bound = 0  # amino acid
M_xanthus.reactions.EX_gly_cys_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_cgly_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_pro_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_alaala_e.lower_bound = 0  # amino acid
M_xanthus.reactions.EX_glu_L_e.lower_bound = 0  # amino acid
M_xanthus.reactions.EX_met_L_e.lower_bound = 0  # amino acid - from Data
M_xanthus.reactions.EX_thr_L_e.lower_bound = 0  # amino acid
M_xanthus.reactions.EX_fru_e.lower_bound = 0  # sugar - from data / article
M_xanthus.reactions.EX_man_e.lower_bound = 0  # sugar - from data / article
# M_xanthus.reactions.EX_malt_e.lower_bound = 0
M_xanthus.reactions.EX_acald_e.lower_bound = 0  # FA - from article
M_xanthus.reactions.EX_acac_e.lower_bound = 0  # FA - from article
# M_xanthus.reactions.EX_glyc3p_e.lower_bound = 0
# M_xanthus.reactions.EX_gam_e.lower_bound = 0
M_xanthus.reactions.EX_fum_e.lower_bound = 0
M_xanthus.reactions.EX_orn_e.lower_bound = 0
# M_xanthus.reactions.EX_succ_e.lower_bound = 0
# M_xanthus.reactions.EX_pi_e.lower_bound = 0 # phosphate - from Data / in env
# M_xanthus.reactions.EX_zn2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_mn2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_mg2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_k_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_cu2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_cobalt2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_cl_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_ca2_e.lower_bound = 0 # Metals - from Data / in env
# M_xanthus.reactions.EX_so4_e.lower_bound = 0 # sulfate - not imported by E.coli / in env
# M_xanthus.reactions.EX_Fe3_e.lower_bound = 0 # Metals - from data ? in env
# M_xanthus.reactions.EX_adocbl_e.lower_bound = 0

# %%
M_xanthus.reactions.EX_glc_D_e.id = (
    "EX_glc__D_e"  # change the name to correspond to E_coli
)

# %% [markdown]
# **Metabolites**
#
# Can choose dynamicly which metabolites there are in the environment

# %%
## Problem need to have right name (ex: here in M_xanthus Ammonium = nothing)


def dynamic_metabolite(model: cobra.core.model.Model, metabolites: dict):
    """Convert the classic metabolites name into reaction used by the model. \n
    :param Model model: The model you want to used. \n
    :param dict y: A dictionary of the metabolite and their quantities in environment. ex: {Biomass: 100}
    """
    # convert to metabolites id
    Metabolites_id = {}
    for i in model.metabolites:
        for j in metabolites:
            if j in i.name:  # check metabolites name
                Metabolites_id[i.id] = j  # save its id if have metabolites in name

    # convert to reaction id
    reaction_id_temp = {}

    for i in model.exchanges._dict:  # filter for only exchange reaction
        for j in Metabolites_id:
            if (
                j in model.reactions.get_by_id(i).reaction and i not in reaction_id_temp
            ):  # check if metabolites in reaction and if not already added
                reaction_id_temp[i] = Metabolites_id[j]  # add the reaction id

    # Filter only the importation
    FBA1 = model.optimize()  # perform FBA
    reaction_id = {}

    for i in reaction_id_temp:
        if FBA1[i] < 0:  # check if flux is below 0 (importation)
            reaction_id[i] = metabolites[
                reaction_id_temp[i]
            ]  # save it with the quantities

    return reaction_id

# %%
FBA_1.__dict__
# Out:
# {'objective_value': 0.0,
#  'status': 'infeasible',
#  'fluxes': CYTDK2             0.000000e+00
#  XPPT               0.000000e+00
#  HXPRT              0.000000e+00
#  NDPK5              0.000000e+00
#  SHK3Dr             0.000000e+00
#                         ...
#  FESD2s             0.000000e+00
#  OCTNLL             0.000000e+00
#  SK_h2o2_c          5.829873e-11
#  DM_o2s_c          -1.255127e-14
#  PR_BIOMASS_PREY    0.000000e+00
#  Name: fluxes, Length: 2715, dtype: float64,
#  'reduced_costs': CYTDK2             0.0
#  XPPT               0.0
#  HXPRT              0.0
#  NDPK5             -0.0
#  SHK3Dr            -0.0
#                    ...
#  FESD2s             0.0
#  OCTNLL             0.0
#  SK_h2o2_c          0.0
#  DM_o2s_c           0.0
#  PR_BIOMASS_PREY    0.0
#  Name: reduced_costs, Length: 2715, dtype: float64,
#  'shadow_prices': octapb_c       0.0
#  cysi__L_e      0.0
#  dhap_c         0.0
#  prbatp_c       0.0
#  10fthf_c      -0.0
#                ...
#  12dgr160_p    -0.0
#  1agpg120_p     0.0
#  tungs_e        0.0
#  5fthf_c       -0.0
#  arbtn_fe3_c   -0.0
#  Name: shadow_prices, Length: 1877, dtype: float64}

# %% [markdown]
# **Dynamic environment**

# %%
t = 0
tf = 120
steps = 0.5
time_point = [0]
it = 1
y = {
    "Glucose": 100,
    "Ammonium": 100,
}  # give the metabolites and their quantities in the environment
biomass = 0  # quantity of Biomass in the environment (at start)
fluxes_E = []
fluxes_M = []
Biomass_E = [0]
Biomass_M = [0]

reactions_list_E_coli = []  # get all reaction of E_coli model
for reaction in E_coli.reactions:
    reactions_list_E_coli.append(reaction.id)

reactions_list_M_xanthus = []
for reaction in M_xanthus.reactions:
    reactions_list_M_xanthus.append(reaction.id)


def add_dynamic_bounds(model: cobra.core.model.Model, y: dict, biomass: int):
    """Use external concentrations to change the bound changing the uptake flux of the limited metabolites. \n
    :param Model model: The model you want to add dynamic bounds. \n
    :param dict y: A list of the metabolite quantities in environment. In order: glucose, amonium. \n
    :param int biomass: Quantities of Biomass in the environment.
    """
    for i in y:
        model.reactions.get_by_id(i).lower_bound = (
            -10 * y[i] / (5 + y[i])
        )  # change the max import value for the metabolites
    max_import = 10 * biomass / (5 + biomass)

    M_xanthus.reactions.EX_glc__D_e.bounds = [0, 0]
    if max_import >= 0:
        M_xanthus.reactions.PR_BIOMASS_PRED.upper_bound = max_import
    else:
        M_xanthus.reactions.PR_BIOMASS_PRED.upper_bound = 0


def update_metabolites(fluxes: list, y: dict, biomass: int):
    """Updtate the metabolites quantities depending of the fluxes. \n
    :param list(int) fluxes: The list of the fluxes. \n
    :param dict y: A list of the metabolite quantities in environment. In order: glucose, amonium, isoleucine. \n
    :param int biomass: Quantities of Biomass in the environment.
    """
    for i in y:
        y[i] = y[i] + fluxes[i]  # calculate the number of metabolites
        if y[i] < 0:
            y[i] = (
                0  # if the value goes below zero set the number of metaboltie to zero
            )

    if "BIOMASS_Ec_iML1515_core_75p37M" in fluxes:
        biomass = biomass + fluxes["BIOMASS_Ec_iML1515_core_75p37M"]
    if "PR_BIOMASS_PRED" in fluxes:
        biomass = biomass - fluxes["PR_BIOMASS_PRED"]

    if biomass < 0:
        biomass = 0

    return y, biomass


y1 = dynamic_metabolite(E_coli, y)
y2 = dynamic_metabolite(M_xanthus, y)
with tqdm(total=tf) as pbar:
    while t < tf:
        add_dynamic_bounds(E_coli, y1, biomass)  ## For Escherichia coli
        FBA_1 = E_coli.optimize()  # perform flux balance analysis (FBA)
        fluxes_E_coli = FBA_1.fluxes.get(
            reactions_list_E_coli
        )  # store the fluxes of the FBA
        fluxes_E_coli *= 0.1  # multiply by Biomass Concentration to get flux
        fluxes_E.append(fluxes_E_coli)  # store all the fluxes
        y, biomass = update_metabolites(fluxes_E_coli, y1, biomass)
        Biomass_E.append(biomass)

        add_dynamic_bounds(M_xanthus, y2, biomass)  ## For Myxococcus xanthus
        FBA_2 = M_xanthus.optimize()
        fluxes_M_xanthus = FBA_2.fluxes.get(reactions_list_M_xanthus)
        fluxes_M_xanthus *= 0.1
        fluxes_M.append(fluxes_M_xanthus)
        y, biomass = update_metabolites(fluxes_M_xanthus, y2, biomass)
        Biomass_M.append(Biomass_M[it - 1] + fluxes_M_xanthus["OF_BIOMASS"])

        same_flux = E_coli.problem.Constraint(
            E_coli.reactions.PR_BIOMASS_PREY.flux_expression - FBA_2.fluxes.get('PR_BIOMASS_PRED'),
            lb=0,
            ub=0)
        E_coli.add_cons_vars(same_flux)

        time_point.append(time_point[it - 1] + steps)
        it += 1
        t += steps
        pbar.update(steps)
# Out:
#   0%|          | 0.5/120 [00:00<01:18,  1.52it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   1%|          | 1.0/120 [00:00<01:27,  1.35it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   1%|▏         | 1.5/120 [00:00<01:07,  1.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   2%|▏         | 2.0/120 [00:01<00:56,  2.08it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   2%|▏         | 2.5/120 [00:01<00:54,  2.16it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   2%|▎         | 3.0/120 [00:01<00:50,  2.32it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   3%|▎         | 3.5/120 [00:01<00:47,  2.44it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   3%|▎         | 4.0/120 [00:01<00:45,  2.54it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   4%|▍         | 4.5/120 [00:02<00:43,  2.64it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   4%|▍         | 5.0/120 [00:02<00:43,  2.64it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   5%|▍         | 5.5/120 [00:02<00:43,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   5%|▌         | 6.0/120 [00:02<00:42,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   5%|▌         | 6.5/120 [00:02<00:42,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   6%|▌         | 7.0/120 [00:02<00:41,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   6%|▋         | 7.5/120 [00:03<00:41,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   7%|▋         | 8.0/120 [00:03<00:41,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   7%|▋         | 8.5/120 [00:03<00:41,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   8%|▊         | 9.0/120 [00:03<00:41,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   8%|▊         | 9.5/120 [00:03<00:40,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   8%|▊         | 10.0/120 [00:04<00:40,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   9%|▉         | 10.5/120 [00:04<00:39,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#   9%|▉         | 11.0/120 [00:04<00:39,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  10%|▉         | 11.5/120 [00:04<00:39,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  10%|█         | 12.0/120 [00:04<00:38,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  10%|█         | 12.5/120 [00:04<00:38,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  11%|█         | 13.0/120 [00:05<00:37,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  11%|█▏        | 13.5/120 [00:05<00:37,  2.87it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  12%|█▏        | 14.0/120 [00:05<00:38,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  12%|█▏        | 14.5/120 [00:05<00:38,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  12%|█▎        | 15.0/120 [00:05<00:38,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  13%|█▎        | 15.5/120 [00:06<00:38,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  13%|█▎        | 16.0/120 [00:06<00:37,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  14%|█▍        | 16.5/120 [00:06<00:37,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  14%|█▍        | 17.0/120 [00:06<00:37,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  15%|█▍        | 17.5/120 [00:06<00:37,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  15%|█▌        | 18.0/120 [00:06<00:37,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  15%|█▌        | 18.5/120 [00:07<00:37,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  16%|█▌        | 19.0/120 [00:07<00:36,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  16%|█▋        | 19.5/120 [00:07<00:36,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  17%|█▋        | 20.0/120 [00:07<00:35,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  17%|█▋        | 20.5/120 [00:07<00:36,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  18%|█▊        | 21.0/120 [00:08<00:35,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  18%|█▊        | 21.5/120 [00:08<00:35,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  18%|█▊        | 22.0/120 [00:08<00:36,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  19%|█▉        | 22.5/120 [00:08<00:35,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  19%|█▉        | 23.0/120 [00:08<00:35,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  20%|█▉        | 23.5/120 [00:08<00:34,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  20%|██        | 24.0/120 [00:09<00:34,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  20%|██        | 24.5/120 [00:09<00:35,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  21%|██        | 25.0/120 [00:09<00:34,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  21%|██▏       | 25.5/120 [00:09<00:34,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  22%|██▏       | 26.0/120 [00:09<00:33,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  22%|██▏       | 26.5/120 [00:10<00:33,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  22%|██▎       | 27.0/120 [00:10<00:33,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  23%|██▎       | 27.5/120 [00:10<00:33,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  23%|██▎       | 28.0/120 [00:10<00:32,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  24%|██▍       | 28.5/120 [00:10<00:33,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  24%|██▍       | 29.0/120 [00:10<00:32,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  25%|██▍       | 29.5/120 [00:11<00:32,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  25%|██▌       | 30.0/120 [00:11<00:31,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  25%|██▌       | 30.5/120 [00:11<00:31,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  26%|██▌       | 31.0/120 [00:11<00:31,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  26%|██▋       | 31.5/120 [00:11<00:31,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  27%|██▋       | 32.0/120 [00:12<00:32,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  27%|██▋       | 32.5/120 [00:12<00:31,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  28%|██▊       | 33.0/120 [00:12<00:30,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  28%|██▊       | 33.5/120 [00:12<00:30,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  28%|██▊       | 34.0/120 [00:12<00:30,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  29%|██▉       | 34.5/120 [00:12<00:30,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  29%|██▉       | 35.0/120 [00:13<00:30,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  30%|██▉       | 35.5/120 [00:13<00:29,  2.83it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  30%|███       | 36.0/120 [00:13<00:29,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  30%|███       | 36.5/120 [00:13<00:29,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  31%|███       | 37.0/120 [00:13<00:30,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  31%|███▏      | 37.5/120 [00:13<00:30,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  32%|███▏      | 38.0/120 [00:14<00:29,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  32%|███▏      | 38.5/120 [00:14<00:29,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  32%|███▎      | 39.0/120 [00:14<00:29,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  33%|███▎      | 39.5/120 [00:14<00:29,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  33%|███▎      | 40.0/120 [00:14<00:29,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  34%|███▍      | 40.5/120 [00:15<00:29,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  34%|███▍      | 41.0/120 [00:15<00:28,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  35%|███▍      | 41.5/120 [00:15<00:28,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  35%|███▌      | 42.0/120 [00:15<00:27,  2.81it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  35%|███▌      | 42.5/120 [00:15<00:27,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  36%|███▌      | 43.0/120 [00:15<00:27,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  36%|███▋      | 43.5/120 [00:16<00:27,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  37%|███▋      | 44.0/120 [00:16<00:27,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  37%|███▋      | 44.5/120 [00:16<00:27,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  38%|███▊      | 45.0/120 [00:16<00:27,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  38%|███▊      | 45.5/120 [00:16<00:26,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  38%|███▊      | 46.0/120 [00:17<00:26,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  39%|███▉      | 46.5/120 [00:17<00:27,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  39%|███▉      | 47.0/120 [00:17<00:26,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  40%|███▉      | 47.5/120 [00:17<00:26,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  40%|████      | 48.0/120 [00:17<00:25,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  40%|████      | 48.5/120 [00:17<00:25,  2.83it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  41%|████      | 49.0/120 [00:18<00:25,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  41%|████▏     | 49.5/120 [00:18<00:25,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  42%|████▏     | 50.0/120 [00:18<00:25,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  42%|████▏     | 50.5/120 [00:18<00:25,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  42%|████▎     | 51.0/120 [00:18<00:25,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  43%|████▎     | 51.5/120 [00:19<00:25,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  43%|████▎     | 52.0/120 [00:19<00:25,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  44%|████▍     | 52.5/120 [00:19<00:24,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  44%|████▍     | 53.0/120 [00:19<00:24,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  45%|████▍     | 53.5/120 [00:19<00:24,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  45%|████▌     | 54.0/120 [00:19<00:24,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  45%|████▌     | 54.5/120 [00:20<00:23,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  46%|████▌     | 55.0/120 [00:20<00:23,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  46%|████▋     | 55.5/120 [00:20<00:24,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  47%|████▋     | 56.0/120 [00:20<00:23,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  47%|████▋     | 56.5/120 [00:20<00:23,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  48%|████▊     | 57.0/120 [00:21<00:23,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  48%|████▊     | 57.5/120 [00:21<00:23,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  48%|████▊     | 58.0/120 [00:21<00:23,  2.64it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  49%|████▉     | 58.5/120 [00:21<00:23,  2.67it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  49%|████▉     | 59.0/120 [00:21<00:22,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  50%|████▉     | 59.5/120 [00:22<00:26,  2.29it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  50%|█████     | 60.0/120 [00:22<00:24,  2.41it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  50%|█████     | 60.5/120 [00:22<00:23,  2.52it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  51%|█████     | 61.0/120 [00:22<00:23,  2.56it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  51%|█████▏    | 61.5/120 [00:22<00:24,  2.42it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  52%|█████▏    | 62.0/120 [00:23<00:22,  2.54it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  52%|█████▏    | 62.5/120 [00:23<00:22,  2.58it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  52%|█████▎    | 63.0/120 [00:23<00:21,  2.62it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  53%|█████▎    | 63.5/120 [00:23<00:21,  2.59it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  53%|█████▎    | 64.0/120 [00:23<00:21,  2.60it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  54%|█████▍    | 64.5/120 [00:24<00:20,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  54%|█████▍    | 65.0/120 [00:24<00:20,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  55%|█████▍    | 65.5/120 [00:24<00:20,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  55%|█████▌    | 66.0/120 [00:24<00:21,  2.50it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  55%|█████▌    | 66.5/120 [00:24<00:20,  2.58it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  56%|█████▌    | 67.0/120 [00:24<00:19,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  56%|█████▋    | 67.5/120 [00:25<00:19,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  57%|█████▋    | 68.0/120 [00:25<00:20,  2.53it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  57%|█████▋    | 68.5/120 [00:25<00:19,  2.60it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  57%|█████▊    | 69.0/120 [00:25<00:19,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  58%|█████▊    | 69.5/120 [00:25<00:21,  2.40it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  58%|█████▊    | 70.0/120 [00:26<00:20,  2.47it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  59%|█████▉    | 70.5/120 [00:26<00:19,  2.58it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  59%|█████▉    | 71.0/120 [00:26<00:18,  2.60it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  60%|█████▉    | 71.5/120 [00:26<00:18,  2.60it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  60%|██████    | 72.0/120 [00:26<00:18,  2.63it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  60%|██████    | 72.5/120 [00:27<00:17,  2.64it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  61%|██████    | 73.0/120 [00:27<00:17,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  61%|██████▏   | 73.5/120 [00:27<00:17,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  62%|██████▏   | 74.0/120 [00:27<00:16,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  62%|██████▏   | 74.5/120 [00:27<00:16,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  62%|██████▎   | 75.0/120 [00:28<00:16,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  63%|██████▎   | 75.5/120 [00:28<00:16,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  63%|██████▎   | 76.0/120 [00:28<00:16,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  64%|██████▍   | 76.5/120 [00:28<00:15,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  64%|██████▍   | 77.0/120 [00:28<00:15,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  65%|██████▍   | 77.5/120 [00:28<00:15,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  65%|██████▌   | 78.0/120 [00:29<00:15,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  65%|██████▌   | 78.5/120 [00:29<00:15,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  66%|██████▌   | 79.0/120 [00:29<00:14,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  66%|██████▋   | 79.5/120 [00:29<00:14,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  67%|██████▋   | 80.0/120 [00:29<00:14,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  67%|██████▋   | 80.5/120 [00:30<00:14,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  68%|██████▊   | 81.0/120 [00:30<00:14,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  68%|██████▊   | 81.5/120 [00:30<00:13,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  68%|██████▊   | 82.0/120 [00:30<00:13,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  69%|██████▉   | 82.5/120 [00:30<00:13,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  69%|██████▉   | 83.0/120 [00:30<00:13,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  70%|██████▉   | 83.5/120 [00:31<00:13,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  70%|███████   | 84.0/120 [00:31<00:13,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  70%|███████   | 84.5/120 [00:31<00:12,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  71%|███████   | 85.0/120 [00:31<00:12,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  71%|███████▏  | 85.5/120 [00:31<00:12,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  72%|███████▏  | 86.0/120 [00:32<00:12,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  72%|███████▏  | 86.5/120 [00:32<00:12,  2.65it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  72%|███████▎  | 87.0/120 [00:32<00:12,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  73%|███████▎  | 87.5/120 [00:32<00:12,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  73%|███████▎  | 88.0/120 [00:32<00:11,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  74%|███████▍  | 88.5/120 [00:32<00:11,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  74%|███████▍  | 89.0/120 [00:33<00:11,  2.66it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  75%|███████▍  | 89.5/120 [00:33<00:11,  2.69it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  75%|███████▌  | 90.0/120 [00:33<00:11,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  75%|███████▌  | 90.5/120 [00:33<00:10,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  76%|███████▌  | 91.0/120 [00:33<00:10,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  76%|███████▋  | 91.5/120 [00:34<00:10,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  77%|███████▋  | 92.0/120 [00:34<00:10,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  77%|███████▋  | 92.5/120 [00:34<00:10,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  78%|███████▊  | 93.0/120 [00:34<00:10,  2.70it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  78%|███████▊  | 93.5/120 [00:34<00:09,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  78%|███████▊  | 94.0/120 [00:35<00:09,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  79%|███████▉  | 94.5/120 [00:35<00:09,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  79%|███████▉  | 95.0/120 [00:35<00:09,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  80%|███████▉  | 95.5/120 [00:35<00:09,  2.68it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  80%|████████  | 96.0/120 [00:35<00:08,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  80%|████████  | 96.5/120 [00:35<00:08,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  81%|████████  | 97.0/120 [00:36<00:08,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  81%|████████▏ | 97.5/120 [00:36<00:08,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  82%|████████▏ | 98.0/120 [00:36<00:08,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  82%|████████▏ | 98.5/120 [00:36<00:07,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  82%|████████▎ | 99.0/120 [00:36<00:07,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  83%|████████▎ | 99.5/120 [00:37<00:07,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  83%|████████▎ | 100.0/120 [00:37<00:07,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  84%|████████▍ | 100.5/120 [00:37<00:07,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  84%|████████▍ | 101.0/120 [00:37<00:06,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  85%|████████▍ | 101.5/120 [00:37<00:06,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  85%|████████▌ | 102.0/120 [00:37<00:06,  2.72it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  85%|████████▌ | 102.5/120 [00:38<00:06,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  86%|████████▌ | 103.0/120 [00:38<00:06,  2.74it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  86%|████████▋ | 103.5/120 [00:38<00:05,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  87%|████████▋ | 104.0/120 [00:38<00:05,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  87%|████████▋ | 104.5/120 [00:38<00:05,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  88%|████████▊ | 105.0/120 [00:38<00:05,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  88%|████████▊ | 105.5/120 [00:39<00:05,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  88%|████████▊ | 106.0/120 [00:39<00:05,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  89%|████████▉ | 106.5/120 [00:39<00:04,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  89%|████████▉ | 107.0/120 [00:39<00:04,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  90%|████████▉ | 107.5/120 [00:39<00:04,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  90%|█████████ | 108.0/120 [00:40<00:04,  2.84it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  90%|█████████ | 108.5/120 [00:40<00:04,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  91%|█████████ | 109.0/120 [00:40<00:03,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  91%|█████████▏| 109.5/120 [00:40<00:03,  2.83it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  92%|█████████▏| 110.0/120 [00:40<00:03,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  92%|█████████▏| 110.5/120 [00:40<00:03,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  92%|█████████▎| 111.0/120 [00:41<00:03,  2.77it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  93%|█████████▎| 111.5/120 [00:41<00:03,  2.81it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  93%|█████████▎| 112.0/120 [00:41<00:02,  2.85it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  94%|█████████▍| 112.5/120 [00:41<00:02,  2.81it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  94%|█████████▍| 113.0/120 [00:41<00:02,  2.80it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  95%|█████████▍| 113.5/120 [00:42<00:02,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  95%|█████████▌| 114.0/120 [00:42<00:02,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  95%|█████████▌| 114.5/120 [00:42<00:01,  2.79it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  96%|█████████▌| 115.0/120 [00:42<00:01,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  96%|█████████▋| 115.5/120 [00:42<00:01,  2.82it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  97%|█████████▋| 116.0/120 [00:42<00:01,  2.83it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  97%|█████████▋| 116.5/120 [00:43<00:01,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  98%|█████████▊| 117.0/120 [00:43<00:01,  2.76it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  98%|█████████▊| 117.5/120 [00:43<00:00,  2.78it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  98%|█████████▊| 118.0/120 [00:43<00:00,  2.71it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  99%|█████████▉| 118.5/120 [00:43<00:00,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#  99%|█████████▉| 119.0/120 [00:44<00:00,  2.73it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# 100%|█████████▉| 119.5/120 [00:44<00:00,  2.75it/s]/home/mickael/miniconda3/envs/Micka_Predation/lib/python3.12/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# 100%|██████████| 120.0/120 [00:44<00:00,  2.70it/s]

# %%
glucose = []
oxygen = []
ammonium = []
biomass = []

for i in fluxes_E:
    glucose.append(i["EX_glc__D_e"])
    biomass.append(i["BIOMASS_Ec_iML1515_core_75p37M"])
    oxygen.append(i["EX_o2_e"])
    ammonium.append(i["EX_nh4_e"])

ax = plt.subplot(111)
ax.plot(time_point[1:], biomass, color="blue", label="Biomass")
ax2 = plt.twinx(ax)
ax2.plot(time_point[1:], glucose, color="red", label="Glucose")
ax2.plot(time_point[1:], oxygen, color="orange", label="Oxygen")
ax2.plot(time_point[1:], ammonium, color="green", label="Ammonium")
ax.set_ylabel("Biomass", color="blue")
ax2.set_ylabel("Imported Metabolite", color="peru")
ax.set_xlabel("Time")

ax.set_title("Fluxes in E.coli")
ax.legend(bbox_to_anchor=(1.15, 1), loc="upper left")
ax2.legend(bbox_to_anchor=(1.15, 0.90), loc="upper left")

# %%
glucose = []
oxygen = []
biomass = []
PR_biomass = []

for i in fluxes_M:
    glucose.append(i["EX_glc__D_e"])
    biomass.append(i["OF_BIOMASS"])
    oxygen.append(i["EX_o2_e"])
    PR_biomass.append(i["PR_BIOMASS_PRED"])

ax = plt.subplot(111)
ax.plot(time_point[1:], biomass, color="blue", label="Biomass")
ax2 = plt.twinx(ax)
ax2.plot(time_point[1:], glucose, color="red", label="Glucose")
ax2.plot(time_point[1:], PR_biomass, color="orange", label="PR_BIOMASS")

ax.set_ylabel("Biomass", color="blue")
ax2.set_ylabel("Imported Metabolite", color="peru")
ax.set_xlabel("Time")

ax.set_title("Fluxes in M.xanthus")
ax.legend(bbox_to_anchor=(1.15, 1), loc="upper left")
ax2.legend(bbox_to_anchor=(1.15, 0.90), loc="upper left")

# %%
biomass_E = []
biomass_M = []

for i in fluxes_M:
    biomass_M.append(i["OF_BIOMASS"])  # taking the biomass flux
for j in fluxes_E:
    biomass_E.append(j["BIOMASS_Ec_iML1515_core_75p37M"])


ax = plt.subplot(111)
ax.plot(
    time_point[1:], biomass_E, color="blue", label="E.coli"
)  # plot the biomass flux of E_coli
ax2 = plt.twinx(ax)
ax2.plot(time_point[1:], biomass_M, color="red", label="M.xanthus")

ax.set_ylabel("Biomass", color="blue")  # set the name
ax2.set_ylabel("Biomass", color="red")
ax.set_xlabel("Time")

ax.set_title("Fluxes of the biomass from E.coli against M.xanthus")  # set the title
ax.legend(bbox_to_anchor=(1.15, 1), loc="upper left")  # show the legend
ax2.legend(bbox_to_anchor=(1.15, 0.90), loc="upper left")

# %%
ax = plt.subplot(111)
ax.plot(
    time_point[1:], Biomass_E[1:], color="blue", label="E.coli"
)  # plot the biomass flux of E_coli
ax2 = plt.twinx(ax)
ax2.plot(time_point[1:], Biomass_M[1:], color="red", label="M.xanthus")

ax.set_ylabel("Biomass", color="blue")  # set the name
ax2.set_ylabel("Biomass", color="red")
ax.set_xlabel("Time")

ax.set_title("Biomass of E.coli against M.xanthus")  # set the title
ax.legend(bbox_to_anchor=(1.15, 1), loc="upper left")  # show the legend
ax2.legend(bbox_to_anchor=(1.15, 0.90), loc="upper left")
